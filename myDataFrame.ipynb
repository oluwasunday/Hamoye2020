# %% [markdown]
# ## pandas weather

# %%
import numpy as np
import pandas as pd

def header(msg):
    print('-' * 50)
    print('[' + msg + ']')

# %%
df_list = {'Month':['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'],
      'avg_high':[45, 54, 76, 76, 23, 86, 66, 77, 87, 54, 55, 76],
      'avg_low':[23, 44, 23, 23, 23, 43, 44, 23, 56, 46, 54, 66],
      'record_high':[77, 65, 76, 54, 23, 77, 65, 56, 87, 77, 55, 89],
      'record_low':[22, 12, 15, 45, 20, 26, 34, 23, 22, 11, 21, 32],
      'avg_precipitation':[4.5, 5.04, 3.76, 2.76, 1.23, 3.86,1.66, 1.7, 3.87, 2.54, 5.5, 4.76],
     }

df = pd.DataFrame(df_list)
header('Weather Prescription')
df
# Out:
# --------------------------------------------------
# [Weather Prescription]
#    Month  avg_high  avg_low  record_high  record_low  avg_precipitation
# 0    Jan        45       23           77          22               4.50
# 1    Feb        54       44           65          12               5.04
# 2    Mar        76       23           76          15               3.76
# 3    Apr        76       23           54          45               2.76
# 4    May        23       23           23          20               1.23
# 5    Jun        86       43           77          26               3.86
# 6    Jul        66       44           65          34               1.66
# 7    Aug        77       23           56          23               1.70
# 8    Sep        87       56           87          22               3.87
# 9    Oct        54       46           77          11               2.54
# 10   Nov        55       54           55          21               5.50
# ...

# %%
header('2 - Weather Prescription - Data from Text File')
filename = 'weather.txt'
df = pd.read_csv(filename)
df
# Out:
# --------------------------------------------------
# [2 - Weather Prescription - Data from Text File]
#    Month   avg_high   avg_low   record_high   record_low   avg_precipitation
# 0    Jan         45        23            77           22                4.50
# 1    Feb         54        44            65           12                5.04
# 2    Mar         76        23            76           15                3.76
# 3    Apr         76        23            54           45                2.76
# 4    May         23        23            23           20                1.23
# 5    Jun         86        43            77           26                3.86
# 6    Jul         66        44            65           34                1.66
# 7    Aug         77        23            56           23                1.70
# 8    Sep         87        56            87           22                3.87
# 9    Oct         54        46            77           11                2.54
# ...

# %%
df.head(5) # prints first 5
# Out:
#   Month   avg_high   avg_low   record_high   record_low   avg_precipitation
# 0   Jan         45        23            77           22                4.50
# 1   Feb         54        44            65           12                5.04
# 2   Mar         76        23            76           15                3.76
# 3   Apr         76        23            54           45                2.76
# 4   May         23        23            23           20                1.23

# %%
df.tail(3) # prints last 3
# Out:
#    Month   avg_high   avg_low   record_high   record_low   avg_precipitation
# 9    Oct         54        46            77           11                2.54
# 10   Nov         55        54            55           21                5.50
# 11   Dec         76        66            89           32                4.76

# %%
df.dtypes
# Out:
# Month                  object
#  avg_high               int64
#  avg_low                int64
#  record_high            int64
#  record_low             int64
#  avg_precipitation    float64
# dtype: object

# %%
df.index
# Out:
# RangeIndex(start=0, stop=12, step=1)

# %%
df.columns
# Out:
# Index(['Month', ' avg_high', ' avg_low', ' record_high', ' record_low',
#        ' avg_precipitation'],
#       dtype='object')

# %%
df.values
# Out:
# array([['Jan', 45, 23, 77, 22, 4.5],
#        ['Feb', 54, 44, 65, 12, 5.04],
#        ['Mar', 76, 23, 76, 15, 3.76],
#        ['Apr', 76, 23, 54, 45, 2.76],
#        ['May', 23, 23, 23, 20, 1.23],
#        ['Jun', 86, 43, 77, 26, 3.86],
#        ['Jul', 66, 44, 65, 34, 1.66],
#        ['Aug', 77, 23, 56, 23, 1.7],
#        ['Sep', 87, 56, 87, 22, 3.87],
#        ['Oct', 54, 46, 77, 11, 2.54],
#        ['Nov', 55, 54, 55, 21, 5.5],
#        ['Dec', 76, 66, 89, 32, 4.76]], dtype=object)

# %%
df.describe()
# Out:
#         avg_high    avg_low   record_high   record_low   avg_precipitation
# count  12.000000  12.000000     12.000000    12.000000           12.000000
# mean   64.583333  39.000000     66.750000    23.583333            3.431667
# std    18.918285  15.486064     18.196528     9.699656            1.429716
# min    23.000000  23.000000     23.000000    11.000000            1.230000
# 25%    54.000000  23.000000     55.750000    18.750000            2.330000
# 50%    71.000000  43.500000     70.500000    22.000000            3.810000
# 75%    76.250000  48.000000     77.000000    27.500000            4.565000
# max    87.000000  66.000000     89.000000    45.000000            5.500000

# %% [markdown]
# ### Slicing

# %%
print(df[2:4]) #rows 2 to 3
# Out:
#   Month   avg_high   avg_low   record_high   record_low   avg_precipitation
# 2   Mar         76        23            76           15                3.76
# 3   Apr         76        23            54           45                2.76

# %%
df.iloc[3:5, [0,3]]
# Out:
#   Month   record_high
# 3   Apr            54
# 4   May            23

# %%
df[df['Month'].isin(['Jun','Jul'])]  #filters months in the dataframe
# Out:
#   Month   avg_high   avg_low   record_high   record_low   avg_precipitation
# 5   Jun         86        43            77           26                3.86
# 6   Jul         66        44            65           34                1.66

# %% [markdown]
# #### Rename column

# %%
df.rename(columns = {'avg_low':'ave_low'}, inplace=True)

df.head()
# Out:
#   Month   avg_high   avg_low   record_high   record_low   avg_precipitation
# 0   Jan         45        23            77           22                4.50
# 1   Feb         54        44            65           12                5.04
# 2   Mar         76        23            76           15                3.76
# 3   Apr         76        23            54           45                2.76
# 4   May         23        23            23           20                1.23

# %%
df.rename(columns = {'avg_low':'ave_low'}, inplace=True)

# %%
df
# Out:
#    Month   avg_high   avg_low   record_high   record_low   avg_precipitation
# 0    Jan         45        23            77           22                4.50
# 1    Feb         54        44            65           12                5.04
# 2    Mar         76        23            76           15                3.76
# 3    Apr         76        23            54           45                2.76
# 4    May         23        23            23           20                1.23
# 5    Jun         86        43            77           26                3.86
# 6    Jul         66        44            65           34                1.66
# 7    Aug         77        23            56           23                1.70
# 8    Sep         87        56            87           22                3.87
# 9    Oct         54        46            77           11                2.54
# 10   Nov         55        54            55           21                5.50
# ...
