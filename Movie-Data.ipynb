# %% [markdown]
# # Movie Dataset - Pandas

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('movie_data.csv', index_col='movie_title')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5043 entries, Avatar  to My Date with Drew
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   director_name         4939 non-null   object
#  1   duration              5028 non-null   float64
#  2   actor_2_name          5030 non-null   object
#  3   genres                5043 non-null   object
#  4   actor_1_name          5036 non-null   object
#  5   num_voted_users       5043 non-null   int64
#  6   actor_3_name          5020 non-null   object
#  7   movie_imdb_link       5043 non-null   object
#  8   num_user_for_reviews  5022 non-null   float64
#  9   language              5031 non-null   object
#  10  country               5038 non-null   object
#  11  title_year            4935 non-null   float64
#  12  imdb_score            5043 non-null   float64
# dtypes: float64(4), int64(1), object(8)
# memory usage: 551.6+ KB

# %%
df.shape
# Out:
# (5043, 13)

# %%
df.head(2)
# Out:
#                                             director_name  duration  \
# movie_title
# Avatar                                      James Cameron     178.0
# Pirates of the Caribbean: At World's End   Gore Verbinski     169.0
#
#                                                actor_2_name  \
# movie_title
# Avatar                                     Joel David Moore
# Pirates of the Caribbean: At World's End      Orlando Bloom
#
#                                                                     genres  \
# movie_title
# Avatar                                     Action|Adventure|Fantasy|Sci-Fi
# Pirates of the Caribbean: At World's End          Action|Adventure|Fantasy
#
#                                           actor_1_name  num_voted_users  \
# movie_title
# Avatar                                     CCH Pounder           886204
# Pirates of the Caribbean: At World's End   Johnny Depp           471220
#
#                                              actor_3_name  \
# ...

# %% [markdown]
# ##### handling duplicates

# %%
df_temp = df.append(df)
df_temp.shape
# Out:
# (10086, 13)

# %%
df_temp.columns
# Out:
# Index(['director_name', 'duration', 'actor_2_name', 'genres', 'actor_1_name',
#        'num_voted_users', 'actor_3_name', 'movie_imdb_link',
#        'num_user_for_reviews', 'language', 'country', 'title_year',
#        'imdb_score'],
#       dtype='object')

# %%
df_temp.rename(columns={'director_name':'director', 'duration':'time'}, inplace=True)

df_temp.columns
# Out:
# Index(['director', 'time', 'actor_2_name', 'genres', 'actor_1_name',
#        'num_voted_users', 'actor_3_name', 'movie_imdb_link',
#        'num_user_for_reviews', 'language', 'country', 'title_year',
#        'imdb_score'],
#       dtype='object')

# %%
df_temp.head(3).isnull() # checks for null values from first 5 data
# Out:
#                                            director   time  actor_2_name  \
# movie_title
# Avatar                                        False  False         False
# Pirates of the Caribbean: At World's End      False  False         False
# Spectre                                       False  False         False
#
#                                            genres  actor_1_name  \
# movie_title
# Avatar                                      False         False
# Pirates of the Caribbean: At World's End    False         False
# Spectre                                     False         False
#
#                                            num_voted_users  actor_3_name  \
# movie_title
# Avatar                                               False         False
# Pirates of the Caribbean: At World's End             False         False
# Spectre                                              False         False
#
#                                            movie_imdb_link  \
# movie_title
# ...

# %%
df_temp.isnull().sum() # checks sum of all null values
# Out:
# director                208
# time                     30
# actor_2_name             26
# genres                    0
# actor_1_name             14
# num_voted_users           0
# actor_3_name             46
# movie_imdb_link           0
# num_user_for_reviews     42
# language                 24
# country                  10
# title_year              216
# imdb_score                0
# dtype: int64

# %% [markdown]
# ### removing null values

# %%
df_temp.dropna(axis=0) # deletes the row where there is null value
df_temp.head(5).isnull()
# Out:
#                                                     director   time  \
# movie_title
# Avatar                                                 False  False
# Pirates of the Caribbean: At World's End               False  False
# Spectre                                                False  False
# The Dark Knight Rises                                  False  False
# Star Wars: Episode VII - The Force Awakens     ...     False   True
#
#                                                     actor_2_name  genres  \
# movie_title
# Avatar                                                     False   False
# Pirates of the Caribbean: At World's End                   False   False
# Spectre                                                    False   False
# The Dark Knight Rises                                      False   False
# Star Wars: Episode VII - The Force Awakens     ...         False   False
#
#                                                     actor_1_name  \
# movie_title
# ...

# %%
df_temp.isnull().sum()
# Out:
# director                208
# time                     30
# actor_2_name             26
# genres                    0
# actor_1_name             14
# num_voted_users           0
# actor_3_name             46
# movie_imdb_link           0
# num_user_for_reviews     42
# language                 24
# country                  10
# title_year              216
# imdb_score                0
# dtype: int64

# %%
df.describe()
# Out:
#           duration  num_voted_users  num_user_for_reviews   title_year  \
# count  5028.000000     5.043000e+03           5022.000000  4935.000000
# mean    107.201074     8.366816e+04            272.770808  2002.470517
# std      25.197441     1.384853e+05            377.982886    12.474599
# min       7.000000     5.000000e+00              1.000000  1916.000000
# 25%      93.000000     8.593500e+03             65.000000  1999.000000
# 50%     103.000000     3.435900e+04            156.000000  2005.000000
# 75%     118.000000     9.630900e+04            326.000000  2011.000000
# max     511.000000     1.689764e+06           5060.000000  2016.000000
#
#         imdb_score
# count  5043.000000
# mean      6.442138
# std       1.125116
# min       1.600000
# 25%       5.800000
# 50%       6.600000
# 75%       7.200000
# max       9.500000

# %%
df_temp['genres'].value_counts().head(5)
# Out:
# Drama                   472
# Comedy                  418
# Comedy|Drama            382
# Comedy|Drama|Romance    374
# Comedy|Romance          316
# Name: genres, dtype: int64

# %%
df_temp['genres'].describe()
# Out:
# count     10086
# unique      914
# top       Drama
# freq        472
# Name: genres, dtype: object

# %%
df.corr()
# Out:
#                       duration  num_voted_users  num_user_for_reviews  \
# duration              1.000000         0.314765              0.328403
# num_voted_users       0.314765         1.000000              0.798406
# num_user_for_reviews  0.328403         0.798406              1.000000
# title_year           -0.135038         0.007397             -0.003147
# imdb_score            0.261662         0.410965              0.292475
#
#                       title_year  imdb_score
# duration               -0.135038    0.261662
# num_voted_users         0.007397    0.410965
# num_user_for_reviews   -0.003147    0.292475
# title_year              1.000000   -0.209167
# imdb_score             -0.209167    1.000000

# %% [markdown]
# ### DataFrame slicing, selecting, extracting

# %%
genre_col = df_temp['genres'] # returns series

# %%
type(genre_col)
# Out:
# pandas.core.series.Series

# %%
genre_col = df_temp[['genres']] #returns DataFrame, since its selecting list of column

# %%
type(genre_col)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ###### Since it's just a list, adding another column name is easy

# %%
subs = df_temp[['genres', 'time']]

# %%
subs.head()
# Out:
#                                                                              genres  \
# movie_title
# Avatar                                              Action|Adventure|Fantasy|Sci-Fi
# Pirates of the Caribbean: At World's End                   Action|Adventure|Fantasy
# Spectre                                                   Action|Adventure|Thriller
# The Dark Knight Rises                                               Action|Thriller
# Star Wars: Episode VII - The Force Awakens     ...                      Documentary
#
#                                                      time
# movie_title
# Avatar                                              178.0
# Pirates of the Caribbean: At World's End            169.0
# Spectre                                             148.0
# The Dark Knight Rises                               164.0
# Star Wars: Episode VII - The Force Awakens     ...    NaN

# %%
df_temp[['genres', 'time']].head(5)
# Out:
#                                                                              genres  \
# movie_title
# Avatar                                              Action|Adventure|Fantasy|Sci-Fi
# Pirates of the Caribbean: At World's End                   Action|Adventure|Fantasy
# Spectre                                                   Action|Adventure|Thriller
# The Dark Knight Rises                                               Action|Thriller
# Star Wars: Episode VII - The Force Awakens     ...                      Documentary
#
#                                                      time
# movie_title
# Avatar                                              178.0
# Pirates of the Caribbean: At World's End            169.0
# Spectre                                             148.0
# The Dark Knight Rises                               164.0
# Star Wars: Episode VII - The Force Awakens     ...    NaN

# %% [markdown]
# ##### .loc - locates by name
# ##### .iloc- locates by numerical index

# %%
tyr = df_temp.iloc[1]

# %%
tyr
# Out:
# director                                                   Gore Verbinski
# time                                                                  169
# actor_2_name                                                Orlando Bloom
# genres                                           Action|Adventure|Fantasy
# actor_1_name                                                  Johnny Depp
# num_voted_users                                                    471220
# actor_3_name                                               Jack Davenport
# movie_imdb_link         http://www.imdb.com/title/tt0449088/?ref_=fn_t...
# num_user_for_reviews                                                 1238
# language                                                          English
# country                                                               USA
# title_year                                                           2007
# imdb_score                                                            7.1
# ...

# %%
movie_subset = df_temp.iloc[1:4]

# %%
movie_subset
# Out:
#                                                     director   time  \
# movie_title
# Pirates of the Caribbean: At World's End      Gore Verbinski  169.0
# Spectre                                           Sam Mendes  148.0
# The Dark Knight Rises                      Christopher Nolan  164.0
#
#                                              actor_2_name  \
# movie_title
# Pirates of the Caribbean: At World's End    Orlando Bloom
# Spectre                                      Rory Kinnear
# The Dark Knight Rises                      Christian Bale
#
#                                                               genres  \
# movie_title
# Pirates of the Caribbean: At World's End    Action|Adventure|Fantasy
# Spectre                                    Action|Adventure|Thriller
# The Dark Knight Rises                                Action|Thriller
#
#                                               actor_1_name  num_voted_users  \
# movie_title
# ...

# %%
cond = (df_temp['director'] == "Sam Mendes")

# %% [markdown]
# ##### You can get used to looking at these conditionals by reading it like:
# ##### Select movies_df where movies_df director equals Sam Mendes.

# %%
cond.head()
# Out:
# movie_title
# Avatar                                                     False
# Pirates of the Caribbean: At World's End                   False
# Spectre                                                     True
# The Dark Knight Rises                                      False
# Star Wars: Episode VII - The Force Awakens                 False
# Name: director, dtype: bool

# %%
df_temp[df_temp['director'] == "Sam Mendes"].head(5) #filter out all movies not directed by Sam Mendes
# Out:
#                        director   time          actor_2_name  \
# movie_title
# Spectre              Sam Mendes  148.0          Rory Kinnear
# Skyfall              Sam Mendes  143.0         Helen McCrory
# Road to Perdition    Sam Mendes  117.0  Jennifer Jason Leigh
# Jarhead              Sam Mendes  125.0        Brian Geraghty
# Revolutionary Road   Sam Mendes  119.0          Kate Winslet
#
#                                         genres       actor_1_name  \
# movie_title
# Spectre              Action|Adventure|Thriller    Christoph Waltz
# Skyfall              Action|Adventure|Thriller      Albert Finney
# Road to Perdition         Crime|Drama|Thriller          Tom Hanks
# Jarhead                       Action|Drama|War    Jake Gyllenhaal
# Revolutionary Road               Drama|Romance  Leonardo DiCaprio
#
#                      num_voted_users      actor_3_name  \
# movie_title
# Spectre                       275868  Stephanie Sigman
# ...

# %%
df_temp[df_temp['imdb_score'] >= 8.6].head(3)
# Out:
#                            director   time   actor_2_name  \
# movie_title
# The Dark Knight   Christopher Nolan  152.0   Heath Ledger
# Interstellar      Christopher Nolan  169.0  Anne Hathaway
# Inception         Christopher Nolan  148.0      Tom Hardy
#
#                                             genres         actor_1_name  \
# movie_title
# The Dark Knight        Action|Crime|Drama|Thriller       Christian Bale
# Interstellar                Adventure|Drama|Sci-Fi  Matthew McConaughey
# Inception         Action|Adventure|Sci-Fi|Thriller    Leonardo DiCaprio
#
#                   num_voted_users          actor_3_name  \
# movie_title
# The Dark Knight           1676169        Morgan Freeman
# Interstellar               928227         Mackenzie Foy
# Inception                 1468200  Joseph Gordon-Levitt
#
#                                                     movie_imdb_link  \
# movie_title
# The Dark Knight   http://www.imdb.com/title/tt0468569/?ref_=fn_t...
# ...

# %%
df_temp.columns[4]
# Out:
# 'actor_1_name'

# %%
df_temp.values[2][4]
# Out:
# 'Christoph Waltz'

# %%
df_temp.head(3)
# Out:
#                                                  director   time  \
# movie_title
# Avatar                                      James Cameron  178.0
# Pirates of the Caribbean: At World's End   Gore Verbinski  169.0
# Spectre                                        Sam Mendes  148.0
#
#                                                actor_2_name  \
# movie_title
# Avatar                                     Joel David Moore
# Pirates of the Caribbean: At World's End      Orlando Bloom
# Spectre                                        Rory Kinnear
#
#                                                                     genres  \
# movie_title
# Avatar                                     Action|Adventure|Fantasy|Sci-Fi
# Pirates of the Caribbean: At World's End          Action|Adventure|Fantasy
# Spectre                                          Action|Adventure|Thriller
#
#                                               actor_1_name  num_voted_users  \
# movie_title
# ...

# %%
df_temp[df_temp['director'].isin(['Christopher Nolan', 'Sam Mendes'])].head()
# Out:
#                                  director   time    actor_2_name  \
# movie_title
# Spectre                        Sam Mendes  148.0    Rory Kinnear
# The Dark Knight Rises   Christopher Nolan  164.0  Christian Bale
# Skyfall                        Sam Mendes  143.0   Helen McCrory
# The Dark Knight         Christopher Nolan  152.0    Heath Ledger
# Interstellar            Christopher Nolan  169.0   Anne Hathaway
#
#                                              genres         actor_1_name  \
# movie_title
# Spectre                   Action|Adventure|Thriller      Christoph Waltz
# The Dark Knight Rises               Action|Thriller            Tom Hardy
# Skyfall                   Action|Adventure|Thriller        Albert Finney
# The Dark Knight         Action|Crime|Drama|Thriller       Christian Bale
# Interstellar                 Adventure|Drama|Sci-Fi  Matthew McConaughey
#
#                         num_voted_users          actor_3_name  \
# movie_title
# ...

# %% [markdown]
# ### Applying functions
# ####  function to convert movies with an 8.0 or greater to a string value of "good" and the rest to "bad" and use this transformed values to create a new column.

# %%
def rating_function(x):
    if x >= 8.0:
        return "good"
    else:
        return "bad"

# %% [markdown]
# df_temp["rating_category"] = df_temp["imdb_score"].apply(rating_function) # rates based on imdb_score

# %% [markdown]
# ###### The .apply() method passes every value in the imdb_score column through the rating_function and then returns a new Series.
# ###### This Series is then assigned to a new column called rating_category.

# %%
df_temp.head(5)
# Out:
#                                                              director   time  \
# movie_title
# Avatar                                                  James Cameron  178.0
# Pirates of the Caribbean: At World's End               Gore Verbinski  169.0
# Spectre                                                    Sam Mendes  148.0
# The Dark Knight Rises                               Christopher Nolan  164.0
# Star Wars: Episode VII - The Force Awakens     ...        Doug Walker    NaN
#
#                                                         actor_2_name  \
# movie_title
# Avatar                                              Joel David Moore
# Pirates of the Caribbean: At World's End               Orlando Bloom
# Spectre                                                 Rory Kinnear
# The Dark Knight Rises                                 Christian Bale
# Star Wars: Episode VII - The Force Awakens     ...        Rob Walker
#
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.rcParams.update({'font.size': 20, 'figure.figsize': (10, 8)}) # set font and plot size to be larger

# %%
df_temp.plot(kind='scatter', x='imdb_score', y='time', title='Revenue (millions) vs Rating');

# %%
df_temp['imdb_score'].plot(kind='hist', title='Rating');
